# %%
# !python examples/logistic_equation.py --config config/logistic_eq.yaml
# Out:
# 2025-03-31 05:33:09,951 - logistic_equation - INFO - Solving Logistic Equation with PINNs
# 2025-03-31 05:33:09,951 - logistic_equation - INFO - Configuration: config/logistic_eq.yaml
# 2025-03-31 05:33:09,951 - logistic_equation - INFO - Device: cpu
# 2025-03-31 05:33:09,964 - logistic_equation - INFO - Model created: SimpleNN
# 2025-03-31 05:33:09,965 - logistic_equation - INFO - Equation created: LogisticEquation
# 2025-03-31 05:33:09,966 - logistic_equation - INFO - Training data loaded: 5 points
# TensorBoard not available. Install with: pip install tensorboard
# 2025-03-31 05:33:09,968 - logistic_equation - INFO - Trainer created: LogisticEquationTrainer
# 2025-03-31 05:33:09,968 - logistic_equation - INFO - Starting training...
# 2025-03-31 05:33:09,968 - logistic_equation - INFO - Time domain: [0.0, 1.5]
# 2025-03-31 05:33:09,968 - logistic_equation - INFO - Number of points: 100
# 2025-03-31 05:33:09,968 - logistic_equation - INFO - Number of collocation points: 10
# ...

# %%
# !python examples/wave_equation.py --config config/wave_eq.yaml
# Out:
# 2025-03-31 05:41:02,191 - wave_equation - INFO - Solving 1D Wave Equation with PINNs
# 2025-03-31 05:41:02,191 - wave_equation - INFO - Configuration: config/wave_eq.yaml
# 2025-03-31 05:41:02,191 - wave_equation - INFO - Device: cpu
# 2025-03-31 05:41:02,201 - wave_equation - INFO - Model created: SimpleNN2
# 2025-03-31 05:41:02,201 - wave_equation - INFO - Equation created: WaveEquation
# TensorBoard not available. Install with: pip install tensorboard
# 2025-03-31 05:41:02,203 - wave_equation - INFO - Trainer created: WaveEquationTrainer
# 2025-03-31 05:41:02,204 - wave_equation - INFO - Starting training...
# 2025-03-31 05:41:02,204 - wave_equation - INFO - Spatial domain: [0.0, 1.0]
# 2025-03-31 05:41:02,204 - wave_equation - INFO - Time domain: [0.0, 1.0]
# 2025-03-31 05:41:02,204 - wave_equation - INFO - Number of points (spatial): 100
# 2025-03-31 05:41:02,204 - wave_equation - INFO - Number of points (time): 150
# ...

# %%
# !python scripts/train.py --config config/logistic_eq.yaml
# Out:
# 2025-03-31 06:31:03,196 - pinns_train_20250331_063103 - INFO - Training PINN for 'logistic' equation
# 2025-03-31 06:31:03,196 - pinns_train_20250331_063103 - INFO - Configuration: config/logistic_eq.yaml
# 2025-03-31 06:31:03,196 - pinns_train_20250331_063103 - INFO - Device: cpu
# 2025-03-31 06:31:03,197 - pinns_train_20250331_063103 - INFO - Model created: SimpleNN
# 2025-03-31 06:31:03,197 - pinns_train_20250331_063103 - INFO - Equation created: LogisticEquation
# TensorBoard not available. Install with: pip install tensorboard
# 2025-03-31 06:31:03,197 - pinns_train_20250331_063103 - INFO - Trainer created: LogisticEquationTrainer
# 2025-03-31 06:31:03,197 - pinns_train_20250331_063103 - INFO - Training data loaded: 5 points
# 2025-03-31 06:31:03,198 - pinns_train_20250331_063103 - INFO - Starting training for logistic equation...
# 2025-03-31 06:31:03,198 - pinns_train_20250331_063103 - INFO - Time domain: [0.0, 1.5]
# ...

# %%
# !python scripts/evaluate.py --config config/logistic_eq.yaml --model-path outputs/models/model_final.pt
# Out:
# 2025-03-31 06:31:25,625 - pinns_evaluate_20250331_063125 - INFO - Evaluating PINN for 'logistic' equation
# 2025-03-31 06:31:25,625 - pinns_evaluate_20250331_063125 - INFO - Configuration: config/logistic_eq.yaml
# 2025-03-31 06:31:25,625 - pinns_evaluate_20250331_063125 - INFO - Device: cpu
# 2025-03-31 06:31:25,626 - pinns_evaluate_20250331_063125 - INFO - Model created: SimpleNN
# 2025-03-31 06:31:25,626 - pinns_evaluate_20250331_063125 - INFO - Equation created: LogisticEquation
# TensorBoard not available. Install with: pip install tensorboard
# 2025-03-31 06:31:25,627 - pinns_evaluate_20250331_063125 - INFO - Trainer created: LogisticEquationTrainer
# 2025-03-31 06:31:25,632 - pinns_evaluate_20250331_063125 - INFO - Model loaded from: outputs/models/model_final.pt (epoch 0)
# 2025-03-31 06:31:25,632 - pinns_evaluate_20250331_063125 - INFO - Evaluating logistic equation model...
# 2025-03-31 06:31:25,632 - pinns_evaluate_20250331_063125 - INFO - Time domain: [0.0, 1.5]
# ...
